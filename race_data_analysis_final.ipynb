# %% [markdown]
# # Race Studio 3 Data Processing
#
# <div class="alert alert-block alert-success">
# <b>TLDR:</b> Scroll to the <a href="#work-with-data" title="Work With Data">Work With Data</a> section at the bottom of this notebook to begin working with the RaceStudio3 data.  Everything above is related to configuration and data processing.
# </div>

# %% [markdown]
# # Initial Configuration
#
# Run this module before running anything else.

# %% [markdown]
# ## Install Necessary Python Packages

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: jupyter in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: numpy in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (1.26.4)
# Requirement already satisfied: scipy in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (1.13.1)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (3.8.4)
# Requirement already satisfied: pint in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (0.23)
# Requirement already satisfied: pint-pandas in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (0.5)
# Requirement already satisfied: pyarrow in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (16.1.0)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (1.5.0)
# Requirement already satisfied: geopy in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (2.4.1)
# Requirement already satisfied: basemap in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (1.4.1)
# Requirement already satisfied: cartopy in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (0.23.0)
# Requirement already satisfied: contextily in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 13)) (1.6.0)
# Requirement already satisfied: numpydoc in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 16)) (1.7.0)
# Requirement already satisfied: pydata-sphinx-theme in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 17)) (0.15.3)
# Requirement already satisfied: sphinx in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 18)) (7.3.7)
# Requirement already satisfied: sphinx_design in ./.venv/lib/python3.12/site-packages (from -r requirements.txt (line 19)) (0.6.0)
# Requirement already satisfied: notebook in ./.venv/lib/python3.12/site-packages (from jupyter->-r requirements.txt (line 1)) (7.2.0)
# Requirement already satisfied: qtconsole in ./.venv/lib/python3.12/site-packages (from jupyter->-r requirements.txt (line 1)) (5.5.2)
# Requirement already satisfied: jupyter-console in ./.venv/lib/python3.12/site-packages (from jupyter->-r requirements.txt (line 1)) (6.6.3)
# Requirement already satisfied: nbconvert in ./.venv/lib/python3.12/site-packages (from jupyter->-r requirements.txt (line 1)) (7.16.4)
# Requirement already satisfied: ipykernel in ./.venv/lib/python3.12/site-packages (from jupyter->-r requirements.txt (line 1)) (6.29.4)
# Requirement already satisfied: ipywidgets in ./.venv/lib/python3.12/site-packages (from jupyter->-r requirements.txt (line 1)) (8.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (23.2)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 5)) (3.1.2)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.12/site-packages (from pint->-r requirements.txt (line 6)) (4.12.1)
# Requirement already satisfied: joblib>=1.2.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn->-r requirements.txt (line 9)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn->-r requirements.txt (line 9)) (3.5.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in ./.venv/lib/python3.12/site-packages (from geopy->-r requirements.txt (line 10)) (2.0)
# Requirement already satisfied: basemap-data<1.4,>=1.3.2 in ./.venv/lib/python3.12/site-packages (from basemap->-r requirements.txt (line 11)) (1.3.2)
# Requirement already satisfied: pyshp<2.4,>=1.2 in ./.venv/lib/python3.12/site-packages (from basemap->-r requirements.txt (line 11)) (2.3.1)
# Requirement already satisfied: pyproj<3.7.0,>=1.9.3 in ./.venv/lib/python3.12/site-packages (from basemap->-r requirements.txt (line 11)) (3.6.1)
# Requirement already satisfied: shapely>=1.7 in ./.venv/lib/python3.12/site-packages (from cartopy->-r requirements.txt (line 12)) (2.0.4)
# Requirement already satisfied: mercantile in ./.venv/lib/python3.12/site-packages (from contextily->-r requirements.txt (line 13)) (1.2.1)
# Requirement already satisfied: rasterio in ./.venv/lib/python3.12/site-packages (from contextily->-r requirements.txt (line 13)) (1.3.10)
# Requirement already satisfied: requests in ./.venv/lib/python3.12/site-packages (from contextily->-r requirements.txt (line 13)) (2.32.3)
# Requirement already satisfied: xyzservices in ./.venv/lib/python3.12/site-packages (from contextily->-r requirements.txt (line 13)) (2024.4.0)
# Requirement already satisfied: tabulate>=0.8.10 in ./.venv/lib/python3.12/site-packages (from numpydoc->-r requirements.txt (line 16)) (0.9.0)
# Requirement already satisfied: beautifulsoup4 in ./.venv/lib/python3.12/site-packages (from pydata-sphinx-theme->-r requirements.txt (line 17)) (4.12.3)
# Requirement already satisfied: docutils!=0.17.0 in ./.venv/lib/python3.12/site-packages (from pydata-sphinx-theme->-r requirements.txt (line 17)) (0.21.2)
# Requirement already satisfied: Babel in ./.venv/lib/python3.12/site-packages (from pydata-sphinx-theme->-r requirements.txt (line 17)) (2.15.0)
# Requirement already satisfied: pygments>=2.7 in ./.venv/lib/python3.12/site-packages (from pydata-sphinx-theme->-r requirements.txt (line 17)) (2.18.0)
# Requirement already satisfied: accessible-pygments in ./.venv/lib/python3.12/site-packages (from pydata-sphinx-theme->-r requirements.txt (line 17)) (0.0.5)
# Requirement already satisfied: sphinxcontrib-applehelp in ./.venv/lib/python3.12/site-packages (from sphinx->-r requirements.txt (line 18)) (1.0.8)
# Requirement already satisfied: sphinxcontrib-devhelp in ./.venv/lib/python3.12/site-packages (from sphinx->-r requirements.txt (line 18)) (1.0.6)
# Requirement already satisfied: sphinxcontrib-jsmath in ./.venv/lib/python3.12/site-packages (from sphinx->-r requirements.txt (line 18)) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in ./.venv/lib/python3.12/site-packages (from sphinx->-r requirements.txt (line 18)) (2.0.5)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in ./.venv/lib/python3.12/site-packages (from sphinx->-r requirements.txt (line 18)) (1.1.10)
# Requirement already satisfied: sphinxcontrib-qthelp in ./.venv/lib/python3.12/site-packages (from sphinx->-r requirements.txt (line 18)) (1.0.7)
# Requirement already satisfied: Jinja2>=3.0 in ./.venv/lib/python3.12/site-packages (from sphinx->-r requirements.txt (line 18)) (3.1.4)
# Requirement already satisfied: snowballstemmer>=2.0 in ./.venv/lib/python3.12/site-packages (from sphinx->-r requirements.txt (line 18)) (2.2.0)
# Requirement already satisfied: alabaster~=0.7.14 in ./.venv/lib/python3.12/site-packages (from sphinx->-r requirements.txt (line 18)) (0.7.16)
# Requirement already satisfied: imagesize>=1.3 in ./.venv/lib/python3.12/site-packages (from sphinx->-r requirements.txt (line 18)) (1.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.12/site-packages (from Jinja2>=3.0->sphinx->-r requirements.txt (line 18)) (2.1.5)
# Requirement already satisfied: certifi in ./.venv/lib/python3.12/site-packages (from pyproj<3.7.0,>=1.9.3->basemap->-r requirements.txt (line 11)) (2024.6.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests->contextily->-r requirements.txt (line 13)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests->contextily->-r requirements.txt (line 13)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests->contextily->-r requirements.txt (line 13)) (2.2.1)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.12/site-packages (from beautifulsoup4->pydata-sphinx-theme->-r requirements.txt (line 17)) (2.5)
# Requirement already satisfied: appnope in ./.venv/lib/python3.12/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in ./.venv/lib/python3.12/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.12/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (1.8.1)
# Requirement already satisfied: ipython>=7.23.1 in ./.venv/lib/python3.12/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (8.25.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./.venv/lib/python3.12/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (8.6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.12/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.12/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (0.1.7)
# Requirement already satisfied: nest-asyncio in ./.venv/lib/python3.12/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: psutil in ./.venv/lib/python3.12/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (5.9.8)
# Requirement already satisfied: pyzmq>=24 in ./.venv/lib/python3.12/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (26.0.3)
# Requirement already satisfied: tornado>=6.1 in ./.venv/lib/python3.12/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (6.4)
# Requirement already satisfied: traitlets>=5.4.0 in ./.venv/lib/python3.12/site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in ./.venv/lib/python3.12/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 1)) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in ./.venv/lib/python3.12/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 1)) (3.0.11)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in ./.venv/lib/python3.12/site-packages (from jupyter-console->jupyter->-r requirements.txt (line 1)) (3.0.46)
# Requirement already satisfied: click>=3.0 in ./.venv/lib/python3.12/site-packages (from mercantile->contextily->-r requirements.txt (line 13)) (8.1.7)
# Requirement already satisfied: bleach!=5.0.0 in ./.venv/lib/python3.12/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (6.1.0)
# Requirement already satisfied: defusedxml in ./.venv/lib/python3.12/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in ./.venv/lib/python3.12/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./.venv/lib/python3.12/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in ./.venv/lib/python3.12/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in ./.venv/lib/python3.12/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.venv/lib/python3.12/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: tinycss2 in ./.venv/lib/python3.12/site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./.venv/lib/python3.12/site-packages (from notebook->jupyter->-r requirements.txt (line 1)) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in ./.venv/lib/python3.12/site-packages (from notebook->jupyter->-r requirements.txt (line 1)) (2.27.2)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in ./.venv/lib/python3.12/site-packages (from notebook->jupyter->-r requirements.txt (line 1)) (4.2.1)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in ./.venv/lib/python3.12/site-packages (from notebook->jupyter->-r requirements.txt (line 1)) (0.2.4)
# Requirement already satisfied: qtpy>=2.4.0 in ./.venv/lib/python3.12/site-packages (from qtconsole->jupyter->-r requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: affine in ./.venv/lib/python3.12/site-packages (from rasterio->contextily->-r requirements.txt (line 13)) (2.4.0)
# Requirement already satisfied: attrs in ./.venv/lib/python3.12/site-packages (from rasterio->contextily->-r requirements.txt (line 13)) (23.2.0)
# Requirement already satisfied: cligj>=0.5 in ./.venv/lib/python3.12/site-packages (from rasterio->contextily->-r requirements.txt (line 13)) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in ./.venv/lib/python3.12/site-packages (from rasterio->contextily->-r requirements.txt (line 13)) (1.4.7)
# Requirement already satisfied: click-plugins in ./.venv/lib/python3.12/site-packages (from rasterio->contextily->-r requirements.txt (line 13)) (1.1.1)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.12/site-packages (from rasterio->contextily->-r requirements.txt (line 13)) (70.0.0)
# Requirement already satisfied: webencodings in ./.venv/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: decorator in ./.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.19.1)
# Requirement already satisfied: stack-data in ./.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in ./.venv/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r requirements.txt (line 1)) (4.2.2)
# Requirement already satisfied: anyio>=3.1.0 in ./.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (4.4.0)
# Requirement already satisfied: argon2-cffi>=21.1 in ./.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in ./.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in ./.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in ./.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in ./.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (0.20.0)
# Requirement already satisfied: send2trash>=1.8.2 in ./.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in ./.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in ./.venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in ./.venv/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter->-r requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in ./.venv/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter->-r requirements.txt (line 1)) (0.27.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./.venv/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter->-r requirements.txt (line 1)) (2.2.5)
# Requirement already satisfied: json5>=0.9.0 in ./.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter->-r requirements.txt (line 1)) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in ./.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter->-r requirements.txt (line 1)) (4.22.0)
# Requirement already satisfied: fastjsonschema>=2.15 in ./.venv/lib/python3.12/site-packages (from nbformat>=5.7->nbconvert->jupyter->-r requirements.txt (line 1)) (2.19.1)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.12/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->-r requirements.txt (line 1)) (0.2.13)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in ./.venv/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (21.2.0)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter->-r requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in ./.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter->-r requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./.venv/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.8.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter->-r requirements.txt (line 1)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter->-r requirements.txt (line 1)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter->-r requirements.txt (line 1)) (0.18.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./.venv/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in ./.venv/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: rfc3339-validator in ./.venv/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./.venv/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: fqdn in ./.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: isoduration in ./.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in ./.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (2.4)
# Requirement already satisfied: uri-template in ./.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in ./.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in ./.venv/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in ./.venv/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./.venv/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 1)) (2.9.0.20240316)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Initialize Python Packages

# %%
import pint
import pandas as pd
import pint_pandas
import numpy as np
import matplotlib.pyplot as plt
import math
import os
import scipy.io
from typing import Iterable, Optional
import cartopy.crs as ccrs
import cartopy.io.img_tiles as cimgt


from race_analysis.constants import *
from race_analysis.units import u


pint_pandas.PintType.ureg = u
u.setup_matplotlib()

# %% [markdown]
# ### Utility Functions

# %% [markdown]
# #### Data Manipulation and Exporting Functions
#
# Useful functions that handle exporting data to `.csv` files, converting series to their base-unit values, and more.

# %%
from race_analysis.df_utils import *
from race_analysis.utils import *
from race_analysis.time_utils import *

# %% [markdown]
# #### Data Exporting Functions
# Useful helper functions for exporting data.

# %%
from race_analysis.export_data import export_data_to_csv

# %% [markdown]
# ### Plotting Functions
#
# Helper functions to simplify the data-plotting process.

# %%
from race_analysis.plot_data import *
from race_analysis.map_data import *

# %% [markdown]
# ### Initialize Race Data from Spreadsheet
#
# This code takes formatted race data from a `.csv` file and parses it into [`Pandas Dataframes`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html), [`Pint`](https://pint.readthedocs.io/en/stable/) Unit objects, and [`Pint Pandas`](https://pint.readthedocs.io/en/0.18/pint-pandas.html) dataframe extension so that computations can be easily performed on the data.

# %% [markdown]
# #### Compute Laps
#
# Since the data exported from RaceStudio3 does not include the lap number or lap-related parameters, the below codeblock uses ML to determine the probable location of the start of the lap (based on the `GPS Latitude` and `GPS Longitude` values and their repetitiveness).  It then initializes a bunch of Lap-specific parameters that would be useful for the analysis.

# %%
from race_analysis.laps_data import *

#####################################################################
#### USE THIS FUNCTION TO UPDATE THE DATA FILES WITH LAP NUMBERS ####
#####################################################################
# # # from race_analysis.laps_data import set_lap_num_in_data_csv
# # # set_lap_num_in_data_csv()

# %% [markdown]
# #### Set Custom Columns
#
# This is where custom columns and math channels are defined.  The master `RACE_DATA_DF` dataframe includes all race data, including columns for these newly defined channels.

# %%
from race_analysis.columns import set_delta

# %% [markdown]
# #### Retrieve Commonly Used Column Names

# %%
from race_analysis.column_names import *

# %% [markdown]
# ### Build RaceStudio3 Dataframe
#
# This is the code that initializes the data structure to be used throughout this Jupyter Notebook.

# %%
from race_analysis.race import *

# %% [markdown]
# # Work with Data

# %% [markdown]
# ## Define Vehicle Constants
#
# These are the constants and values associated with the car, as well as where said values were sourced.

# %%
from race_analysis.constants import *

#### MOTOR SPECIFICATIONS ####
electric_motor_mass = 22 * u.kg             # https://www.electricmotorsport.com/me1616-brushless-65hp-liquid-cooled-ipm-motor-24-120v.html
"""Mass of the ME1616 electric motor"""

electric_power_continuous = 20 * u.kW       # https://www.electricmotorsport.com/me1616-brushless-65hp-liquid-cooled-ipm-motor-24-120v.html
"""Continuous power for the ME1616 electric motor"""
electric_power_peak = 55 * u.kW             # https://www.electricmotorsport.com/me1616-brushless-65hp-liquid-cooled-ipm-motor-24-120v.html
"""Peak power for the ME1616 electric motor"""

electric_stall_torque = 134 * u.N * u.m     # https://www.electricmotorsport.com/me1616-brushless-65hp-liquid-cooled-ipm-motor-24-120v.html
"""Stall torque for the ME1616 electric motor"""
electric_continuous_torque = 55 * u.N * u.m # https://www.miromax.lt/userfiles/6/files/ME%20MAX%201507_1616%20%20AIR_Water%20Cooled%2020kW_55kW_96V_.pdf
"""Continuous torque for the ME1616 electric motor at 250 Amps"""
##############################

#### BASIC CALCULATIONS ####
torque_gas = (POWER_GAS_AT_WHEELS / PEAK_GAS_RPM).to(u.N * u.m)
"""Torque of the gas-powered vehicle"""
TMR_gas = torque_gas / MASS_CAR
"""Torque-Mass ratio of the gas-powered vehicle"""
PMR_gas = POWER_GAS_AT_WHEELS / MASS_CAR
"""Power-Mass ratio of the gas-powered vehicle"""
############################

print(f'PEAK GAS ANGULAR SPEED \t{PEAK_GAS_RPM.to_base_units()}')
print(f'GAS POWER IN WATTS     \t{POWER_GAS_AT_WHEELS.to(u.W)}')
print(f'TORQUE OF GAS MOTOR    \t{torque_gas}')
print(f'TORQUE-MASS RATIO (GAS)\t{TMR_gas}')
print(f'POWER-MASS RATIO (GAS) \t{PMR_gas.to(u.kW / u.kg)}')

avg_power = (.5 * electric_power_continuous + .5 * electric_power_peak)
on_elec_per_lap = 30 * u.sec
num_laps = 25

total_energy = avg_power*on_elec_per_lap*num_laps
print(f'TOTAL ENERGY\t\t{total_energy.to(u.kWh)}')
print(f'AVERAGE POWER\t\t{avg_power}')
operating_voltage = 96 * u.V
print(f'OPERATING AMPERAGE\t{(avg_power/operating_voltage).to(u.amp)}')
print(f'TOTAL AMP HOURS\t\t{(total_energy / operating_voltage).to(u.amp * u.hr)}')

print(f'EV ENERGY PER LAP\t{(total_energy / num_laps).to(u.kWh)}')

battery_mass_density = 55 * u.Wh / u.lb

print(f'BATTERY MASS\t\t{(total_energy / battery_mass_density).to_base_units()}')



max_axle_rpm = 2400 * u.rpm
distance_per_revolution = (2 * RADIUS_WHEEL_BACK * math.pi) / u.revolution
distance_per_minute = max_axle_rpm * distance_per_revolution
print(distance_per_minute.to('mph'))
# Out:
# PEAK GAS ANGULAR SPEED 	1235.6931104119853 radian / second
# GAS POWER IN WATTS     	108126.48137942917 watt
# TORQUE OF GAS MOTOR    	87.50269825764373 meter * newton
# TORQUE-MASS RATIO (GAS)	0.17057056190573827 meter * newton / kilogram
# POWER-MASS RATIO (GAS) 	0.21077286818602176 kilowatt / kilogram
# TOTAL ENERGY		7.8125 kilowatt_hour
# AVERAGE POWER		37.5 kilowatt
# OPERATING AMPERAGE	390.625 ampere
# TOTAL AMP HOURS		81.38020833333334 ampere * hour
# EV ENERGY PER LAP	0.3125 kilowatt_hour
# BATTERY MASS		64.43073437500001 kilogram
# 161.91458200319622 mile_per_hour

# %% [markdown]
# ## Load in Data
#
# Define the filepath of the data file you are trying to load in, as well as the corresponding `units` dictionary containing that dataset's units values.
#
# > The `units` dictionary is helpful, but not critical due to Pint's builtin unit-handling capabilities.  This is a remnant of an older implementation of some functionality that @HenryAsa hasn't yet removed.

# %%
RACE_DATA_FILES_TO_USE = {
    f'{DATA_DIRECTORY}/BETTER_20230831_143833_Blair Hosie_Rush SR 150_Palmer ACW_a_0045.csv': {'lap_num': 5, 'track_name': 'Palmer'},
    f'{DATA_DIRECTORY}/BETTER_20240127_1528_Blair Hosie_Rush SR 0003_PODIUM_Generic testing_a_1215.csv': {'lap_num': 7, 'track_name': 'Podium'},
}
UNITS: dict[str, str] = {}

# %%
def get_simple_statistics(df: pd.DataFrame | pd.Series, column_name: str, lap_num: int, units: str):
    print(f"##### SUMMARY STATISTICS FOR {column_name.upper()} #####")
    # (df[df[COL_LAP_NUM] == lap_num][column_name].pint.m_as(units)).to_csv("BLA1.csv")
    filtered_df = df[df[COL_LAP_NUM] == lap_num][column_name].pint.m_as(units)
    round_amount = 2
    print(f"Mean & {round(filtered_df.mean(), round_amount)} \\\\")
    print(f"Standard Deviation & {round(filtered_df.std(), round_amount)} \\\\")
    print(f"Minimum & {round(filtered_df.min(), round_amount)} \\\\")
    print(f'5th Percentile & {round(np.percentile(filtered_df, 5), round_amount)} \\\\')
    print(f'10th Percentile & {round(np.percentile(filtered_df, 10), round_amount)} \\\\')
    print(f'25th Percentile & {round(np.percentile(filtered_df, 25), round_amount)} \\\\')
    print(f'Median (50th Percentile) & {round(np.percentile(filtered_df, 50), round_amount)} \\\\')
    print(f'75th Percentile & {round(np.percentile(filtered_df, 75), round_amount)} \\\\')
    print(f'90th Percentile & {round(np.percentile(filtered_df, 90), round_amount)} \\\\')
    print(f'95th Percentile & {round(np.percentile(filtered_df, 95), round_amount)} \\\\')
    print(f"Maximum & {round(filtered_df.max(), round_amount)} \\\\")
    print(f"##############################{'#' * len(column_name)}######\n")

# %% [markdown]
# ## Generate Plots for Data

# %%
def calculate_cumulative_ke_change_during_braking(group):
    units = str(group['Delta KE'].pint.units)
    cumulative_sum = 0 * u(units)
    cumulative_ke_change = []

    for index, row in group.iterrows():
        if row[COL_BRAKING_ON] == 1:
            cumulative_sum -= row['Delta KE']
        else:
            cumulative_sum = 0 * u(units)
        cumulative_ke_change.append(cumulative_sum)

    return pd.Series(cumulative_ke_change, index=group.index, dtype=f'pint[{units}]')


def regen_calculations(df: pd.DataFrame, data_filepath: str, lap_num: int, track_name: Optional[str] = None) -> None:
    print(f'Plotting Regen Calculations')

    cumulative_ke_change_during_braking = pd.Series(
        1 * df.groupby(COL_LAP_NUM).apply(
        calculate_cumulative_ke_change_during_braking)
        .reset_index(level=0, drop=True),
        name='Kinetic Energy Recuperated During Braking',
    )

    energy_units = 'kilowatthours'

    plot_map(
        df=df,
        data_to_plot=cumulative_ke_change_during_braking,
        data_units=energy_units,
        lap_num=lap_num,
        colorbar_label="Kinetic Energy [Kilowatt Hours]",
        tile_source=MapType.GOOGLE_SATELITE,
        data_filepath=data_filepath,
        show_plots=False,
        save_plots=True,
        track_name=RACE_DATA_FILES_TO_USE[data_filepath]['track_name'],
        # set_custom_colors={0: 'dimgray'},
    )

def plot_cumulative_regen(df: pd.DataFrame, data_filepath: str, lap_num: int):
    energy_units = 'kilowatthours'
    cumulative_ke_change_during_braking = pd.Series(data=(
        df.groupby(COL_LAP_NUM)[[COL_LAP_NUM, 'Delta KE', COL_BRAKING_ON]].apply(
        lambda x: (-1 * x['Delta KE'] * x[COL_BRAKING_ON]).cumsum())),
        name='Cumulative Energy Recuperation During Braking'
    ).reset_index(level=0, drop=True)

    print(f'\tPlotting Cumulative Regen')

    plot_map(
        df=df,
        data_to_plot=cumulative_ke_change_during_braking.pint.to(energy_units),
        data_units=energy_units,
        lap_num=lap_num,
        colorbar_label=f'KiloWatt Hours',
        tile_source=MapType.GOOGLE_SATELITE,
        data_filepath=data_filepath,
        save_plots=True,
        show_plots=False,
        track_name=RACE_DATA_FILES_TO_USE[data_filepath]['track_name'],
    )


def plot_final_for_all_tracks(
        save_plots: bool = True,
        show_plots: bool = False,
    ) -> None:
    save_or_show_plot(save_plots=save_plots, show_plots=show_plots)

    data_files = get_data_files()

    for data_filepath in data_files:
        #### REMOVE LATER ####
        if data_filepath not in RACE_DATA_FILES_TO_USE:
            continue
        ######################
        UNITS: dict[str, str] = {}
        race_data_df = load_race(race_data_filepath=data_filepath, units=UNITS)
        lap_num = RACE_DATA_FILES_TO_USE[data_filepath]['lap_num']
        track_name = RACE_DATA_FILES_TO_USE[data_filepath]['track_name']

        print(f'################\n{track_name}\n################\n')


        for column_name in ["SDS FUEL2 msx10", 'ThrottlePercent', COL_BRAKING_ON, 'Front Brake V', 'Rear Brake V', 'Front Brake p', 'Rear Brake p']:
            try:
                race_data_df = normalize_column(df=race_data_df, column_name=column_name, new_min=0, new_max=100, lap_num=lap_num, normalized_units='percent')
                if column_name == 'SDS FUEL2 msx10':
                    race_data_df = race_data_df.rename(columns={f'{column_name} - Normalized': 'ThrottlePercent - Normalized'})
                    column_name = 'ThrottlePercent'
                # get_simple_statistics(df=race_data_df, column_name=f'{column_name} - Normalized', lap_num=lap_num, units='percent')
            except Exception as error:
                print(f'Couldn\'t normalize column "{column_name}"')
                print(f'{error}')

        export_data_to_csv(data_dfs=race_data_df, filename=f'MANGO_{track_name}.csv')

        regen_calculations(df=race_data_df, data_filepath=data_filepath, lap_num=lap_num, track_name=track_name)
        plot_cumulative_regen(df=race_data_df, data_filepath=data_filepath, lap_num=lap_num)

        generate_simple_speed_plots(df=race_data_df, data_filepath=data_filepath, lap_num=lap_num, track_name=track_name)
        generate_simple_throttle_percent(df=race_data_df, data_filepath=data_filepath, lap_num=lap_num, track_name=track_name)

        series_to_plot = {
            'GPS Speed': {
                'name': 'Vehicle Speed',
                'data': race_data_df['GPS Speed'],
                'units': 'mph',
            },
            'GPS BRK On': {
                'name': 'Braking On',
                'data': race_data_df['GPS BRK On'],
                'units': 'dimensionless',
            },
            'Front Brake V': {
                'name': 'Front Braking Voltage',
                'data': race_data_df['Front Brake V'],
                'units': 'millivolts',
            },
            'GPS LatAcc': {
                'name': 'Lateral Acceleration',
                'data': race_data_df['GPS LatAcc'],
                'units': 'standard_gravity',
                'units_name': 'gravity',
            },
            'GPS LonAcc': {
                'name': 'Longitudinal Acceleration',
                'data': race_data_df['GPS LonAcc'],
                'units': 'standard_gravity',
                'units_name': 'gravity',
            },
            'Front Brake V': {
                'name': 'Front Braking Pressure',
                'data': race_data_df['Front Brake V'],
                'units': 'volts',
            },
            'Rear Brake V': {
                'name': 'Rear Braking Pressure',
                'data': race_data_df['Rear Brake V'],
                'units': 'volts',
            },
            'Front Brake V - Normalized': {
                'name': 'Front Braking Percentage',
                'data': race_data_df['Front Brake V - Normalized'],
                'units': 'percent',
            },
            'Rear Brake V - Normalized': {
                'name': 'Front Braking Percentage',
                'data': race_data_df['Rear Brake V - Normalized'],
                'units': 'percent',
            },
        }

        for column_name, column_params in series_to_plot.items():
            print(f'\tPlotting {column_params["name"]}')
            data_to_plot = column_params['data']
            column_units = column_params['units']

            get_simple_statistics(race_data_df, column_name=column_name, lap_num=lap_num, units=column_units)

            plot_map(
                df=race_data_df,
                data_to_plot=data_to_plot,
                data_units=column_units,
                lap_num=lap_num,
                colorbar_label=f'{column_params["name"]}  [{column_units if "units_name" not in column_params else column_params["units_name"]}]',
                tile_source=MapType.GOOGLE_SATELITE,
                data_filepath=data_filepath,
                save_plots=save_plots,
                show_plots=show_plots,
                track_name=track_name,
            )



        ##### THROTTLE PERCENTAGE #####
        tricky_series_to_plot = {
            'ThrottlePercent': {
                'name': 'Throttle Percentage',
                # 'data': race_data_df['ThrottlePercent'],
                'units': 'percent'
            },
            'SDS FUEL2 msx10': {
                'name': 'Throttle Percentage',
                # 'data': race_data_df['SDS FUEL2 msx10'],
                'units': 'dimensionless'
            }
        }

        for column_name, column_params in tricky_series_to_plot.items():
            print(f'\tPlotting Tricky {column_name}')
            normalized_column_name = f'{column_name} - Normalized'
            try:
                data_to_plot = race_data_df[normalized_column_name]
            except:
                print(f'\tSKIPPING {column_name}')
                continue

            column_units = column_params['units']

            get_simple_statistics(race_data_df, column_name=normalized_column_name, lap_num=lap_num, units=column_units)

            plot_map(
                df=race_data_df,
                data_to_plot=data_to_plot,
                data_units=column_units,
                lap_num=lap_num,
                colorbar_label=f'{column_params["name"]}  [percent]',
                tile_source=MapType.GOOGLE_SATELITE,
                data_filepath=data_filepath,
                save_plots=save_plots,
                show_plots=show_plots,
                track_name=track_name,
            )


def generate_simple_speed_plots(df: pd.DataFrame, data_filepath: str, lap_num: int, track_name: Optional[str] = None):

    print(f'Generating Simple Speed Plots')

    #### VEHICLE SPEED FOR ALL LAPS VS. DISTANCE ####
    lap_indices = get_lap_indices(df)

    for current_lap_num in get_usable_lap_nums(data_filepath):
        start_lap_index, end_lap_index = lap_indices[current_lap_num]

        valid_car_distance = slice_into_df(df['Distance on GPS Speed'], start_lap_index, end_lap_index)
        reset_distances = valid_car_distance - valid_car_distance.iloc[0]
        valid_car_speeds = slice_into_df(df['GPS Speed'], start_lap_index, end_lap_index)
        plt.plot(reset_distances.pint.to('miles'), valid_car_speeds.pint.to('mph'), label=f'Lap {current_lap_num - 1}')

    plt.xlabel(f'Distance Traveled [miles]')
    plt.ylabel(f'Vehicle Speed [mph]')
    plt.legend()
    plot_title = f'{f"{track_name} - " if track_name is not None else ""}Speed for Each Lap'
    # plt.title(plot_title)
    save_plot(data_file=f'{data_filepath}', name=plot_title)
    reset_plot()
    #################################################

    #### VEHICLE SPEED FOR SINGLE LAP VS. DISTANCE ####
    lap_indices = get_lap_indices(df)

    # for lap_num in get_usable_lap_nums(data_filepath):
    start_lap_index, end_lap_index = lap_indices[lap_num]

    valid_car_distance = slice_into_df(df['Distance on GPS Speed'], start_lap_index, end_lap_index)
    reset_distances = valid_car_distance - valid_car_distance.iloc[0]
    valid_car_speeds = slice_into_df(df['GPS Speed'], start_lap_index, end_lap_index)
    plt.plot(reset_distances.pint.to('miles'), valid_car_speeds.pint.to('mph'))
    plt.xlabel(f'Distance Traveled [{reset_distances.pint.to("miles").pint.units}]')
    plt.ylabel(f'Vehicle Speed  [{valid_car_speeds.pint.to("mph").pint.units}]')
    # plt.title(f'Vehicle Speed for Lap {lap_num}')
    plot_title = f'{f"{track_name} - " if track_name is not None else ""}Speed for Lap {lap_num}'
    save_plot(data_file=f'{data_filepath}', name=plot_title, lap_num=lap_num)
    reset_plot()
    #################################################


def generate_simple_throttle_percent(df: pd.DataFrame, data_filepath: str, lap_num: int, track_name: Optional[str] = None):

    print(f'Generating Simple Throttle Percent Plots')

    COL_THROTTLE_NORMALIZED = 'ThrottlePercent - Normalized'
    COL_BRK_ON_NORMALIZED = f'{COL_BRAKING_ON} - Normalized'

    #### VEHICLE THROTTLE PERCENT FOR ALL LAPS VS. DISTANCE ####
    lap_indices = get_lap_indices(df)

    for current_lap_num in get_usable_lap_nums(data_filepath):
        start_lap_index, end_lap_index = lap_indices[current_lap_num]

        valid_car_distance = slice_into_df(df['Distance on GPS Speed'], start_lap_index, end_lap_index)
        reset_distances = valid_car_distance - valid_car_distance.iloc[0]
        valid_throttle_percent = slice_into_df(df[COL_THROTTLE_NORMALIZED], start_lap_index, end_lap_index)
        valid_brk_on = slice_into_df(df[COL_BRK_ON_NORMALIZED], start_lap_index, end_lap_index)
        plt.plot(reset_distances.pint.to('miles'), valid_throttle_percent, label=f'Throttle Percent (Lap {current_lap_num - 1})')
        plt.plot(reset_distances.pint.to('miles'), valid_brk_on, label=f'Braking On (Lap {current_lap_num - 1})')

    plt.xlabel(f'Distance Traveled [miles]')
    plt.ylabel(f'Throttle/Brake Percentage [percent]')
    plt.legend()
    plot_title = f'{f"{track_name} - " if track_name is not None else ""}ThrottlePercent for Each Lap'
    # plt.title(plot_title)
    save_plot(data_file=f'{data_filepath}', name=plot_title)
    reset_plot()
    #################################################

    #### VEHICLE THROTTLE PERCENT FOR SINGLE LAP VS. DISTANCE ####
    lap_indices = get_lap_indices(df)

    # for lap_num in get_usable_lap_nums(data_filepath):
    start_lap_index, end_lap_index = lap_indices[lap_num]

    valid_car_distance = slice_into_df(df['Distance on GPS Speed'], start_lap_index, end_lap_index)
    reset_distances = valid_car_distance - valid_car_distance.iloc[0]
    valid_throttle_percent = slice_into_df(df[COL_THROTTLE_NORMALIZED], start_lap_index, end_lap_index)
    valid_brk_on = slice_into_df(df[COL_BRK_ON_NORMALIZED], start_lap_index, end_lap_index)
    valid_front_brk_v = slice_into_df(df[f'Front Brake V - Normalized'], start_lap_index, end_lap_index)
    valid_front_brk_p = slice_into_df(df[f'Front Brake p - Normalized'], start_lap_index, end_lap_index)

    plt.stackplot(reset_distances.pint.m_as('miles'), valid_throttle_percent.pint.m_as('percent'), labels=['Throttle Percentage'])
    plt.xlabel(f'Distance Traveled [miles]')
    plt.ylabel(f'Throttle Percentage  [percent]')
    plt.legend()
    plot_title = f'{f"{track_name} - " if track_name is not None else ""}ThrottlePercent for Lap {lap_num}'
    save_plot(data_file=f'{data_filepath}', name=plot_title, lap_num=lap_num)
    reset_plot()

    plt.stackplot(reset_distances.pint.m_as('miles'), valid_throttle_percent.pint.m_as('percent'), valid_front_brk_p.pint.m_as('percent'), labels=['Throttle Percentage', 'Braking Percentage'])
    plt.xlabel(f'Distance Traveled [miles]')
    plt.ylabel(f'Throttle + Brake Percentage  [percent]')
    plt.legend()
    plot_title = f'{f"{track_name} - " if track_name is not None else ""}ThrottleBrakePercent for Lap {lap_num}'
    save_plot(data_file=f'{data_filepath}', name=plot_title, lap_num=lap_num)
    reset_plot()
    #################################################

plot_final_for_all_tracks()
# Out:
# ################
# Palmer
# ################
#
# Couldn't normalize column "SDS FUEL2 msx10"
# 'SDS FUEL2 msx10'
# NORMALIZING DATA - SETTING NORMALIZED UNITS: SETTING TO percent
# NORMALIZING DATA - SETTING NORMALIZED UNITS: SETTING TO percent
# NORMALIZING DATA - SETTING NORMALIZED UNITS: SETTING TO percent
# NORMALIZING DATA - SETTING NORMALIZED UNITS: SETTING TO percent
# NORMALIZING DATA - SETTING NORMALIZED UNITS: SETTING TO percent
# NORMALIZING DATA - SETTING NORMALIZED UNITS: SETTING TO percent
# Plotting Regen Calculations
# /var/folders/9f/x5qsm0vn5yd3x_9c71rrqcd40000gn/T/ipykernel_43177/4013528399.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   1 * df.groupby(COL_LAP_NUM).apply(
# 	Plotting Cumulative Regen
# Generating Simple Speed Plots
# Generating Simple Throttle Percent Plots
# 	Plotting Vehicle Speed
# ##### SUMMARY STATISTICS FOR GPS SPEED #####
# Mean & 75.53 \\
# Standard Deviation & 21.23 \\
# Minimum & 43.73 \\
# 5th Percentile & 47.54 \\
# 10th Percentile & 50.56 \\
# 25th Percentile & 58.45 \\
# Median (50th Percentile) & 70.33 \\
# 75th Percentile & 90.87 \\
# 90th Percentile & 106.14 \\
# 95th Percentile & 118.69 \\
# Maximum & 123.29 \\
# #############################################
#
# 	Plotting Braking On
# ##### SUMMARY STATISTICS FOR GPS BRK ON #####
# Mean & 0.22 \\
# Standard Deviation & 0.41 \\
# Minimum & 0 \\
# 5th Percentile & 0.0 \\
# 10th Percentile & 0.0 \\
# 25th Percentile & 0.0 \\
# Median (50th Percentile) & 0.0 \\
# 75th Percentile & 0.0 \\
# 90th Percentile & 1.0 \\
# 95th Percentile & 1.0 \\
# Maximum & 1 \\
# ##############################################
#
# 	Plotting Front Braking Pressure
# ##### SUMMARY STATISTICS FOR FRONT BRAKE V #####
# Mean & 0.64 \\
# Standard Deviation & 0.46 \\
# Minimum & 0.48 \\
# 5th Percentile & 0.49 \\
# 10th Percentile & 0.49 \\
# 25th Percentile & 0.49 \\
# Median (50th Percentile) & 0.5 \\
# 75th Percentile & 0.5 \\
# 90th Percentile & 0.93 \\
# 95th Percentile & 1.93 \\
# Maximum & 2.92 \\
# #################################################
#
# 	Plotting Lateral Acceleration
# ##### SUMMARY STATISTICS FOR GPS LATACC #####
# Mean & -0.21 \\
# Standard Deviation & 0.89 \\
# Minimum & -1.65 \\
# 5th Percentile & -1.36 \\
# 10th Percentile & -1.28 \\
# 25th Percentile & -1.07 \\
# Median (50th Percentile) & -0.24 \\
# 75th Percentile & 0.53 \\
# 90th Percentile & 1.06 \\
# 95th Percentile & 1.25 \\
# Maximum & 1.72 \\
# ##############################################
#
# 	Plotting Longitudinal Acceleration
# ##### SUMMARY STATISTICS FOR GPS LONACC #####
# Mean & 0.01 \\
# Standard Deviation & 0.32 \\
# Minimum & -1.25 \\
# 5th Percentile & -0.72 \\
# 10th Percentile & -0.41 \\
# 25th Percentile & -0.13 \\
# Median (50th Percentile) & 0.09 \\
# 75th Percentile & 0.22 \\
# 90th Percentile & 0.31 \\
# 95th Percentile & 0.36 \\
# Maximum & 0.56 \\
# ##############################################
#
# 	Plotting Rear Braking Pressure
# ##### SUMMARY STATISTICS FOR REAR BRAKE V #####
# Mean & 0.62 \\
# Standard Deviation & 0.36 \\
# Minimum & 0.5 \\
# 5th Percentile & 0.5 \\
# 10th Percentile & 0.5 \\
# 25th Percentile & 0.5 \\
# Median (50th Percentile) & 0.51 \\
# 75th Percentile & 0.51 \\
# 90th Percentile & 0.81 \\
# 95th Percentile & 1.63 \\
# Maximum & 2.38 \\
# ################################################
#
# 	Plotting Front Braking Percentage
# ##### SUMMARY STATISTICS FOR FRONT BRAKE V - NORMALIZED #####
# Mean & 6.54 \\
# Standard Deviation & 18.78 \\
# Minimum & 0.0 \\
# 5th Percentile & 0.25 \\
# 10th Percentile & 0.33 \\
# 25th Percentile & 0.37 \\
# Median (50th Percentile) & 0.53 \\
# 75th Percentile & 0.66 \\
# 90th Percentile & 18.5 \\
# 95th Percentile & 59.41 \\
# Maximum & 100.0 \\
# ##############################################################
#
# 	Plotting Front Braking Percentage
# ##### SUMMARY STATISTICS FOR REAR BRAKE V - NORMALIZED #####
# Mean & 6.51 \\
# Standard Deviation & 19.05 \\
# Minimum & 0.0 \\
# 5th Percentile & 0.16 \\
# 10th Percentile & 0.21 \\
# 25th Percentile & 0.32 \\
# Median (50th Percentile) & 0.48 \\
# 75th Percentile & 0.64 \\
# 90th Percentile & 16.55 \\
# 95th Percentile & 60.08 \\
# Maximum & 100.0 \\
# #############################################################
#
# 	Plotting Tricky ThrottlePercent
# ##### SUMMARY STATISTICS FOR THROTTLEPERCENT - NORMALIZED #####
# Mean & 54.99 \\
# Standard Deviation & 39.32 \\
# Minimum & 0.0 \\
# 5th Percentile & 5.31 \\
# 10th Percentile & 6.19 \\
# 25th Percentile & 10.62 \\
# Median (50th Percentile) & 53.98 \\
# 75th Percentile & 99.12 \\
# 90th Percentile & 99.12 \\
# 95th Percentile & 99.12 \\
# Maximum & 100.0 \\
# ################################################################
#
# 	Plotting Tricky SDS FUEL2 msx10
# 	SKIPPING SDS FUEL2 msx10
# ################
# Podium
# ################
#
# NORMALIZING DATA - SETTING NORMALIZED UNITS: SETTING TO percent
# Couldn't normalize column "ThrottlePercent"
# 'ThrottlePercent'
# NORMALIZING DATA - SETTING NORMALIZED UNITS: SETTING TO percent
# NORMALIZING DATA - SETTING NORMALIZED UNITS: SETTING TO percent
# NORMALIZING DATA - SETTING NORMALIZED UNITS: SETTING TO percent
# NORMALIZING DATA - SETTING NORMALIZED UNITS: SETTING TO percent
# NORMALIZING DATA - SETTING NORMALIZED UNITS: SETTING TO percent
# Plotting Regen Calculations
# /var/folders/9f/x5qsm0vn5yd3x_9c71rrqcd40000gn/T/ipykernel_43177/4013528399.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   1 * df.groupby(COL_LAP_NUM).apply(
# 	Plotting Cumulative Regen
# Generating Simple Speed Plots
# Generating Simple Throttle Percent Plots
# 	Plotting Vehicle Speed
# ##### SUMMARY STATISTICS FOR GPS SPEED #####
# Mean & 80.33 \\
# Standard Deviation & 19.67 \\
# Minimum & 40.44 \\
# 5th Percentile & 48.93 \\
# 10th Percentile & 54.83 \\
# 25th Percentile & 65.23 \\
# Median (50th Percentile) & 80.12 \\
# 75th Percentile & 93.61 \\
# 90th Percentile & 109.27 \\
# 95th Percentile & 115.09 \\
# Maximum & 121.34 \\
# #############################################
#
# 	Plotting Braking On
# ##### SUMMARY STATISTICS FOR GPS BRK ON #####
# Mean & 0.27 \\
# Standard Deviation & 0.45 \\
# Minimum & 0 \\
# 5th Percentile & 0.0 \\
# 10th Percentile & 0.0 \\
# 25th Percentile & 0.0 \\
# Median (50th Percentile) & 0.0 \\
# 75th Percentile & 1.0 \\
# 90th Percentile & 1.0 \\
# 95th Percentile & 1.0 \\
# Maximum & 1 \\
# ##############################################
#
# 	Plotting Front Braking Pressure
# ##### SUMMARY STATISTICS FOR FRONT BRAKE V #####
# Mean & 0.91 \\
# Standard Deviation & 1.17 \\
# Minimum & 0.46 \\
# 5th Percentile & 0.47 \\
# 10th Percentile & 0.48 \\
# 25th Percentile & 0.49 \\
# Median (50th Percentile) & 0.5 \\
# 75th Percentile & 0.51 \\
# 90th Percentile & 2.59 \\
# 95th Percentile & 4.67 \\
# Maximum & 4.86 \\
# #################################################
#
# 	Plotting Lateral Acceleration
# ##### SUMMARY STATISTICS FOR GPS LATACC #####
# Mean & -0.19 \\
# Standard Deviation & 0.82 \\
# Minimum & -1.54 \\
# 5th Percentile & -1.31 \\
# 10th Percentile & -1.23 \\
# 25th Percentile & -0.97 \\
# Median (50th Percentile) & -0.08 \\
# 75th Percentile & 0.22 \\
# 90th Percentile & 1.18 \\
# 95th Percentile & 1.26 \\
# Maximum & 1.49 \\
# ##############################################
#
# 	Plotting Longitudinal Acceleration
# ##### SUMMARY STATISTICS FOR GPS LONACC #####
# Mean & 0.01 \\
# Standard Deviation & 0.39 \\
# Minimum & -1.21 \\
# 5th Percentile & -0.91 \\
# 10th Percentile & -0.58 \\
# 25th Percentile & -0.19 \\
# Median (50th Percentile) & 0.13 \\
# 75th Percentile & 0.27 \\
# 90th Percentile & 0.37 \\
# 95th Percentile & 0.4 \\
# Maximum & 0.66 \\
# ##############################################
#
# 	Plotting Rear Braking Pressure
# ##### SUMMARY STATISTICS FOR REAR BRAKE V #####
# Mean & -0.03 \\
# Standard Deviation & 0.0 \\
# Minimum & -0.03 \\
# 5th Percentile & -0.03 \\
# 10th Percentile & -0.03 \\
# 25th Percentile & -0.03 \\
# Median (50th Percentile) & -0.03 \\
# 75th Percentile & -0.03 \\
# 90th Percentile & -0.03 \\
# 95th Percentile & -0.03 \\
# Maximum & -0.03 \\
# ################################################
#
# 	Plotting Front Braking Percentage
# ##### SUMMARY STATISTICS FOR FRONT BRAKE V - NORMALIZED #####
# Mean & 10.21 \\
# Standard Deviation & 26.48 \\
# Minimum & 0.0 \\
# 5th Percentile & 0.32 \\
# 10th Percentile & 0.41 \\
# 25th Percentile & 0.61 \\
# Median (50th Percentile) & 0.84 \\
# 75th Percentile & 1.07 \\
# 90th Percentile & 48.34 \\
# 95th Percentile & 95.54 \\
# Maximum & 100.0 \\
# ##############################################################
#
# 	Plotting Front Braking Percentage
# ##### SUMMARY STATISTICS FOR REAR BRAKE V - NORMALIZED #####
# Mean & 48.96 \\
# Standard Deviation & 16.67 \\
# Minimum & 0.0 \\
# 5th Percentile & 25.0 \\
# 10th Percentile & 25.0 \\
# 25th Percentile & 50.0 \\
# Median (50th Percentile) & 50.0 \\
# 75th Percentile & 50.0 \\
# 90th Percentile & 75.0 \\
# 95th Percentile & 75.0 \\
# Maximum & 100.0 \\
# #############################################################
#
# 	Plotting Tricky ThrottlePercent
# ##### SUMMARY STATISTICS FOR THROTTLEPERCENT - NORMALIZED #####
# Mean & 60.96 \\
# Standard Deviation & 37.34 \\
# Minimum & 0.0 \\
# 5th Percentile & 1.2 \\
# 10th Percentile & 1.2 \\
# 25th Percentile & 21.69 \\
# Median (50th Percentile) & 87.95 \\
# 75th Percentile & 90.36 \\
# 90th Percentile & 92.77 \\
# 95th Percentile & 96.39 \\
# Maximum & 100.0 \\
# ################################################################
#
# 	Plotting Tricky SDS FUEL2 msx10
# 	SKIPPING SDS FUEL2 msx10

# %% [markdown]
# ## Determine Drag Coefficient of the Vehicle
#
# $$F_D = \frac{1}{2}\rho v^2 C_D A$$
# where $F_D$ is the drag force, $\rho$ is the density of the fluid (air), $v$ is the speed of the vehicle relative to the fluid, $C_D$ is the drag coefficient, and $A$ is the cross-sectional area of the vehicle.
#
# Rearranged, the coefficient of drag can be determined by:
#
# $$C_D = \frac{2 F_D}{\rho v^2 A}$$

# %%
# def plot_coefficient_of_drag(df: pd.DataFrame, units: dict[str, str]) -> None:

#     #### Drag Calculations ####
#     speed_during_coast = columns_during_state(
#         df=RACE_DATA_DF,
#         data_columns='GPS Speed',
#         state_columns='GPS CST On',
#         append_to_column_name='During Coasting',
#         fill_with_zeros=True,
#     )
#     acceleration_during_coast = columns_during_state(
#         df=RACE_DATA_DF,
#         data_columns='Acceleration',
#         state_columns='GPS CST On',
#         append_to_column_name='During Coasting',
#         fill_with_zeros=True,
#     )

#     drag_force = pd.Series(data=acceleration_during_coast * MASS_VEHICLE, name='Drag Force')
#     drag_coefficient = pd.Series(data=((2*drag_force) / (RHO_AIR * (speed_during_coast**2) * VEHICLE_CROSS_SECTIONAL_AREA)), name='Coefficient of Drag')
#     ###########################

#     legend_values = []
#     lap_indices = get_lap_indices(df)

#     for lap_num in get_usable_lap_nums(RACE_DATA_FILEPATH):
#         start_lap_index, end_lap_index = lap_indices[lap_num]

#         valid_lap_times = slice_into_df(df[COL_TIME], start_lap_index, end_lap_index)
#         valid_drag_coefficients = slice_into_df(drag_coefficient, start_lap_index, end_lap_index)

#         legend_values.append(f'Lap {lap_num}')
#         plt.title(f'Coefficient of Drag')
#         plot_data(valid_lap_times, f'Time ({units[COL_TIME]})', valid_drag_coefficients.pint.to_base_units(), f'Coefficient of Drag ({valid_drag_coefficients.pint.to_base_units().pint.units})')
#         plt.legend(legend_values)
#         # plt.show()

# plot_coefficient_of_drag(df=RACE_DATA_DF, units=UNITS)

# %% [markdown]
# # Plotting

# %%
# cumulative_ke_change = pd.Series(data=RACE_DATA_DF.groupby(COL_LAP_NUM)['Delta KE'].apply(lambda x: x.cumsum()))

# abs_cumulative_ke_change_during_coast = pd.Series(data=(
#     RACE_DATA_DF.groupby(COL_LAP_NUM)[[COL_LAP_NUM, 'Delta KE', 'GPS CST On']].apply(
#     lambda x: abs((x['Delta KE'] * x['GPS CST On'])).cumsum())),    # ABS removes pint units from this object
#     name='Absolute Value Cumulative KE Change During Coasting'
# ).reset_index(level=0, drop=True)

# # cumulative_ke_change_during_coast = pd.Series(data=(RACE_DATA_DF * RACE_DATA_DF['GPS CST On']).groupby(COL_LAP_NUM)['Delta KE'].apply(lambda x: x.cumsum()))
# # cumulative_ke_change_during_coast = pd.Series(data=strip_df_of_units(RACE_DATA_DF.groupby(COL_LAP_NUM)['Delta KE']).cumsum(), dtype=f'pint[{UNITS["Delta KE"]}]')

# plt.title(f'Cumulative Change in Kinetic Energy by Lap')
# plot_data(RACE_DATA_DF[COL_TIME], f'Time ({UNITS[COL_TIME]})', abs_cumulative_ke_change_during_coast.pint.to_base_units(), f'Cumulative Change in Kinetic Energy ({abs_cumulative_ke_change_during_coast.pint.to_base_units().pint.units})')

# lap_indices = get_lap_indices(RACE_DATA_DF)

# for lap_num in get_usable_lap_nums(RACE_DATA_FILEPATH):
#     start_lap_index, end_lap_index = lap_indices[lap_num]

#     valid_lap_times = slice_into_df(RACE_DATA_DF[COL_TIME], start_lap_index, end_lap_index)
#     lap_cum_KE = slice_into_df(abs_cumulative_ke_change_during_coast, start_lap_index, end_lap_index)

#     plt.title(f'Cumulative Change in Kinetic Energy for Lap {lap_num}')
#     plot_data(valid_lap_times, f'Time ({UNITS[COL_TIME]})', lap_cum_KE.pint.to_base_units(), f'Cumulative Change in Kinetic Energy ({lap_cum_KE.pint.to_base_units().pint.units})')

# %% [markdown]
# ## Regenerative Braking Calculations

# %% [markdown]
# ### Simple Cumulative Change in Kinetic Energy During Braking

# %%
# def regen_calculations(df: pd.DataFrame, data_filepath: str) -> None:

#     cumulative_ke_change = pd.Series(data=df.groupby(COL_LAP_NUM)['Delta KE'].apply(lambda x: x.cumsum()))

#     cumulative_ke_change_during_braking = pd.Series(data=(
#         df.groupby(COL_LAP_NUM)[[COL_LAP_NUM, 'Delta KE', COL_BRAKING_ON]].apply(
#         lambda x: (-1 * x['Delta KE'] * x[COL_BRAKING_ON]).cumsum())),
#         name='Energy Recuperation During Braking'
#     ).reset_index(level=0, drop=True)

#     lap_indices = get_lap_indices(df)
#     energy_units = 'kilowatthours'

#     for lap_num in get_usable_lap_nums(data_filepath):
#         start_lap_index, end_lap_index = lap_indices[lap_num]

#         valid_lap_times = slice_into_df(df[COL_TIME], start_lap_index, end_lap_index)
#         zeroed_lap_times = reset_lap_times(valid_lap_times)

#         lap_cum_KE = slice_into_df(cumulative_ke_change_during_braking, start_lap_index, end_lap_index)
#         valid_car_distance = slice_into_df(df['Distance on GPS Speed'], start_lap_index, end_lap_index)
#         reset_distances = valid_car_distance - valid_car_distance.iloc[0]

#         # plt.plot(zeroed_lap_times, lap_cum_KE.pint.to(energy_units), label=f'Lap {lap_num}')
#         plt.plot(reset_distances.pint.to('miles'), lap_cum_KE.pint.to(energy_units), label=f'Lap {lap_num}')
#         # plot_data(zeroed_lap_times, f'Time ({UNITS["Time"]})', reset_distances.pint.to('miles'), f'Vehicle Speed ({valid_car_distance.pint.to("miles").pint.units})')

#     plt.xlabel(f'Distance Traveled [miles]')
#     # plt.xlabel(f'Time ({UNITS[COL_TIME]})')
#     plt.ylabel(f'Change in Kinetic Energy ({lap_cum_KE.pint.to(energy_units).pint.units})')
#     plt.legend()
#     plt.title(f'Cumulative Change in Kinetic Energy During Braking')
#     # save_plot(data_filepath)
#     plt.show()


# def determine_regen_for_all_data():
#     data_files = get_data_files()

#     for data_filepath in data_files:
#         #### REMOVE LATER ####
#         if data_filepath not in RACE_DATA_FILES_TO_USE:
#             continue
#         ######################
#         print(data_filepath)
#         UNITS: dict[str, str] = {}
#         race_data_df = load_race(race_data_filepath=data_filepath, units=UNITS)

#         regen_calculations(race_data_df, data_filepath)

# determine_regen_for_all_data()

# # regen_calculations(RACE_DATA_DF, RACE_DATA_FILEPATH)

# %% [markdown]
# ### Cumulative Change in KE During Braking Each Brake-Cycle

# %%
# def calculate_cumulative_ke_change_during_braking(group):
#     units = str(group['Delta KE'].pint.units)
#     cumulative_sum = 0 * u(units)
#     cumulative_ke_change = []

#     for index, row in group.iterrows():
#         if row[COL_BRAKING_ON] == 1:
#             cumulative_sum += row['Delta KE']
#         else:
#             cumulative_sum = 0 * u(units)
#         cumulative_ke_change.append(cumulative_sum)

#     return pd.Series(cumulative_ke_change, index=group.index, dtype=f'pint[{units}]')


# def regen_calculations(df: pd.DataFrame, data_filepath: str) -> None:
#     cumulative_ke_change_during_braking = pd.Series(
#         -1 * df.groupby(COL_LAP_NUM).apply(
#         calculate_cumulative_ke_change_during_braking)
#         .reset_index(level=0, drop=True),
#         name='Cumulative KE Change During Braking',
#     )

#     lap_indices = get_lap_indices(df)
#     energy_units = 'kilowatthours'

#     plot_map_every_lap(
#         df=RACE_DATA_DF,
#         data_to_plot=cumulative_ke_change_during_braking,
#         data_units=energy_units,
#         colorbar_label="Kinetic Energy [Kilowatt Hours]",
#         tile_source=MapType.GOOGLE_SATELITE,
#         data_filepath=RACE_DATA_FILEPATH,
#         show_plots=True,
#         save_plots=False,
#     )



# def determine_regen_for_all_data():
#     data_files = get_data_files()

#     for data_filepath in data_files:
#         #### REMOVE LATER ####
#         if data_filepath not in RACE_DATA_FILES_TO_USE:
#             continue
#         ######################
#         print(data_filepath)
#         UNITS: dict[str, str] = {}
#         race_data_df = load_race(race_data_filepath=data_filepath, units=UNITS)

#         regen_calculations(race_data_df, data_filepath)

# determine_regen_for_all_data()
# # regen_calculations(RACE_DATA_DF, RACE_DATA_FILEPATH)

# %% [markdown]
# ## Actual Graphs

# %% [markdown]
# ### Cumulative Regen

# %%
# def plot_cumulative_regen_all_tracks(
#         save_plots: bool = False,
#         show_plots: bool = True,
#     ) -> None:
#     save_or_show_plot(save_plots=save_plots, show_plots=show_plots)

#     data_files = get_data_files()

#     for data_filepath in data_files:
#         #### REMOVE LATER ####
#         if data_filepath not in RACE_DATA_FILES_TO_USE:
#             continue
#         ######################

#         UNITS: dict[str, str] = {}
#         race_data_df = load_race(race_data_filepath=data_filepath, units=UNITS)

#         energy_units = 'kilowatthours'
#         cumulative_ke_change_during_braking = pd.Series(data=(
#             race_data_df.groupby(COL_LAP_NUM)[[COL_LAP_NUM, 'Delta KE', COL_BRAKING_ON]].apply(
#             lambda x: (-1 * x['Delta KE'] * x[COL_BRAKING_ON]).cumsum())),
#             name='Energy Recuperation During Braking'
#         ).reset_index(level=0, drop=True)

#         plot_map_every_lap(
#             df=race_data_df,
#             data_to_plot=cumulative_ke_change_during_braking.pint.to(energy_units),
#             data_units=energy_units,
#             colorbar_label=f'KiloWatt Hours',
#             tile_source=MapType.GOOGLE_SATELITE,
#             data_filepath=data_filepath,
#             save_plots=save_plots,
#             show_plots=show_plots,
#         )

# plot_cumulative_regen_all_tracks()

# %% [markdown]
# ### Parameters During Braking

# %%
# def plot_all_columns_during_braking(
#         df: pd.DataFrame,
#         data_filepath: str,
#         save_plots: bool = True,
#         show_plots: bool = False,
#     ) -> None:
#     save_or_show_plot(save_plots=save_plots, show_plots=show_plots)

#     for data_column in df.columns:
#         data_during_braking = columns_during_state(
#             df=df,
#             data_columns=data_column,
#             state_columns=COL_BRAKING_ON,
#             append_to_column_name='During Braking',
#             fill_with_zeros=True,
#         )
#         data_during_braking = pd.Series(data=(
#             df.groupby(COL_LAP_NUM)[[COL_LAP_NUM, 'Delta KE', COL_BRAKING_ON]].apply(
#             lambda x: (x['Delta KE'] * x[COL_BRAKING_ON]).cumsum())),
#             name='Energy Recuperation During Braking'
#         ).reset_index(level=0, drop=True).pint.to_base_units()

#         data_units = data_during_braking.pint.units
#         plot_map(
#             df=df,
#             data_to_plot=data_during_braking.pint.to_base_units(),
#             data_units=data_during_braking.pint.units,
#             lap_num=3,
#             colorbar_label=f'{str(df[data_column].pint.dimensionality).capitalize()} ({data_units})',
#             tile_source=MapType.GOOGLE_SATELITE,
#             data_filepath=data_filepath,
#             save_plots=save_plots,
#             show_plots=show_plots,
#         )

# plot_all_columns_during_braking(RACE_DATA_DF, RACE_DATA_FILEPATH)

# %%
# cumulative_ke_change = pd.Series(data=RACE_DATA_DF.groupby(COL_LAP_NUM)['Delta KE'].apply(lambda x: x.cumsum()))

# cumulative_ke_change_during_braking = pd.Series(data=(
#     RACE_DATA_DF.groupby(COL_LAP_NUM)[[COL_LAP_NUM, 'Delta KE', COL_BRAKING_ON]].apply(
#     lambda x: abs((x['Delta KE'] * x[COL_BRAKING_ON])).cumsum())),
#     name='Cumulative KE Change During Braking'
# ).reset_index(level=0, drop=True)

# # abs_cumulative_ke_change_during_braking = pd.Series(data=(
# #     RACE_DATA_DF.groupby(COL_LAP_NUM)[[COL_LAP_NUM, 'Delta KE', COL_BRAKING_ON]].apply(
# #     lambda x: abs((x['Delta KE'] * x[COL_BRAKING_ON])).cumsum())),
# #     name='Absolute Value Cumulative KE Change During Braking'
# # ).reset_index(level=0, drop=True)

# # cumulative_ke_change_during_coast = pd.Series(data=(RACE_DATA_DF * RACE_DATA_DF['GPS CST On']).groupby(COL_LAP_NUM)['Delta KE'].apply(lambda x: x.cumsum()))
# # cumulative_ke_change_during_coast = pd.Series(data=strip_df_of_units(RACE_DATA_DF.groupby(COL_LAP_NUM)['Delta KE']).cumsum(), dtype=f'pint[{UNITS["Delta KE"]}]')

# plt.title(f'Cumulative Change in Kinetic Energy by Lap')
# plot_data(RACE_DATA_DF[COL_TIME], f'Time ({UNITS[COL_TIME]})', abs_cumulative_ke_change_during_braking.pint.to_base_units(), f'Cumulative Change in Kinetic Energy ({abs_cumulative_ke_change_during_coast.pint.to_base_units().pint.units})')

# lap_indices = get_lap_indices(RACE_DATA_DF)

# for lap_num in get_usable_lap_nums(RACE_DATA_FILEPATH):
#     start_lap_index, end_lap_index = lap_indices[lap_num]

#     valid_lap_times = slice_into_df(RACE_DATA_DF[COL_TIME], start_lap_index, end_lap_index)
#     lap_cum_KE = slice_into_df(abs_cumulative_ke_change_during_braking, start_lap_index, end_lap_index)

#     plt.title(f'Cumulative Change in Kinetic Energy During Braking for Lap {lap_num}')
#     plot_data(
#         valid_lap_times,
#         f'Time ({UNITS[COL_TIME]})',
#         lap_cum_KE.pint.to_base_units(),
#         f'Cumulative Change in Kinetic Energy ({lap_cum_KE.pint.to_base_units().pint.units})'
#     )

# %%
# #### VEHICLE SPEED FOR EACH LAP VS. TIME ####
# # lap_indices = get_lap_indices(RACE_DATA_DF)

# # for lap_num in get_usable_lap_nums(RACE_DATA_FILEPATH):
# #     start_lap_index, end_lap_index = lap_indices[lap_num]

# #     valid_lap_times = slice_into_df(RACE_DATA_DF['Time'], start_lap_index, end_lap_index)
# #     zeroed_lap_times = np.linspace(0, valid_lap_times.iloc[-1] - valid_lap_times.iloc[0], len(valid_lap_times))
# #     valid_car_speeds = slice_into_df(RACE_DATA_DF['GPS Speed'], start_lap_index, end_lap_index)
# #     plt.plot(zeroed_lap_times, valid_car_speeds.pint.to('mph'), label=f'Lap {lap_num}')
# #     # plot_data(zeroed_lap_times, f'Time ({UNITS["Time"]})', valid_car_speeds.pint.to('mph'), f'Vehicle Speed ({valid_car_speeds.pint.to("mph").pint.units})')

# # plt.xlabel(f'Time ({UNITS["Time"]})')
# # plt.ylabel(f'Vehicle Speed ({valid_car_speeds.pint.to("mph").pint.units})')
# # plt.legend()
# # plt.title(f'Vehicle Speed for Each Lap')
# # plt.show()
# #############################################


# #### VEHICLE SPEED FOR EACH LAP VS. DISTANCE ####
# lap_indices = get_lap_indices(RACE_DATA_DF)

# for lap_num in get_usable_lap_nums(RACE_DATA_FILEPATH):
#     start_lap_index, end_lap_index = lap_indices[lap_num]

#     valid_car_distance = slice_into_df(RACE_DATA_DF['Distance on GPS Speed'], start_lap_index, end_lap_index)
#     reset_distances = valid_car_distance - valid_car_distance.iloc[0]
#     valid_car_speeds = slice_into_df(RACE_DATA_DF['GPS Speed'], start_lap_index, end_lap_index)
#     plt.plot(reset_distances.pint.to('miles'), valid_car_speeds.pint.to('mph'), label=f'Lap {lap_num}')

# plt.xlabel(f'Distance Traveled ({reset_distances.pint.to("miles").pint.units})')
# plt.ylabel(f'Vehicle Speed ({valid_car_speeds.pint.to("mph").pint.units})')
# plt.legend()
# plt.title(f'Vehicle Speed at Specific Point for Each Lap')
# save_plot(data_file=RACE_DATA_FILEPATH)
# plt.show()
# #################################################


# lap_indices = get_lap_indices(RACE_DATA_DF)

# for lap_num in get_usable_lap_nums(RACE_DATA_FILEPATH):
#     start_lap_index, end_lap_index = lap_indices[lap_num]

#     valid_lap_times = slice_into_df(RACE_DATA_DF['Time'], start_lap_index, end_lap_index)
#     zeroed_lap_times = np.linspace(0, valid_lap_times.iloc[-1] - valid_lap_times.iloc[0], len(valid_lap_times))
#     valid_car_distance = slice_into_df(RACE_DATA_DF['Distance on GPS Speed'], start_lap_index, end_lap_index)
#     reset_distances = valid_car_distance - valid_car_distance.iloc[0]
#     plt.plot(zeroed_lap_times, reset_distances.pint.to('miles'), label=f'Lap {lap_num}')
#     # plot_data(zeroed_lap_times, f'Time ({UNITS["Time"]})', reset_distances.pint.to('miles'), f'Vehicle Speed ({valid_car_distance.pint.to("miles").pint.units})')

# plt.legend()
# plt.xlabel(f'Time ({UNITS["Time"]})')
# plt.ylabel(f'Distance Traveled ({reset_distances.pint.to("miles").pint.units})')
# plt.title(f'Distance Traveled for Each Lap')
# plt.show()

# %%
lap_indices = get_lap_indices(RACE_DATA_DF)

for lap_num in get_usable_lap_nums(RACE_DATA_FILEPATH):
    start_lap_index, end_lap_index = lap_indices[lap_num]

    valid_lap_times = slice_into_df(RACE_DATA_DF['Time'], start_lap_index, end_lap_index)
    zeroed_lap_times = np.linspace(0, valid_lap_times.iloc[-1] - valid_lap_times.iloc[0], len(valid_lap_times))
    valid_car_distance = slice_into_df(RACE_DATA_DF['Distance on GPS Speed'], start_lap_index, end_lap_index)
    reset_distances = valid_car_distance - valid_car_distance.iloc[0]
    plt.plot(zeroed_lap_times, reset_distances.pint.to('miles'), label=f'Lap {lap_num}')
    # plot_data(zeroed_lap_times, f'Time ({UNITS["Time"]})', reset_distances.pint.to('miles'), f'Vehicle Speed ({valid_car_distance.pint.to("miles").pint.units})')

plt.legend()
plt.xlabel(f'Time ({UNITS[COL_TIME]})')
plt.ylabel(f'Distance Traveled ({reset_distances.pint.to("miles").pint.units})')
plt.title(f'Distance Traveled for Each Lap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 lap_indices = get_lap_indices(RACE_DATA_DF)
#       3 for lap_num in get_usable_lap_nums(RACE_DATA_FILEPATH):
#       4     start_lap_index, end_lap_index = lap_indices[lap_num]
#
# NameError: name 'RACE_DATA_DF' is not defined

# %% [markdown]
# ## Maps

# %%
from race_analysis.map_data import plot_map_every_lap

# %% [markdown]
# ### Plot GPS Speed

# %%
def plot_GPS_Speed(
        df: pd.DataFrame,
        data_filepath: Optional[str] = None,
        save_plots: bool = True,
        show_plots: bool = False,
    ) -> None:
    save_or_show_plot(save_plots=save_plots, show_plots=show_plots)

    data_name = 'GPS Speed'
    plot_units = 'mph'
    colorbar_label = f'Velocity [{plot_units}]'
    data_filepath = data_filepath if data_filepath is not None else RACE_DATA_FILEPATH

    plot_map_every_lap(
        df=df,
        data_to_plot=df[data_name],
        data_units=plot_units,
        colorbar_label=colorbar_label,
        tile_source=MapType.GOOGLE_SATELITE,
        data_filepath=data_filepath,
        save_plots=save_plots,
        show_plots=show_plots,
    )

    if save_plots:
        save_plot(data_filepath)

# plot_GPS_Speed(df=RACE_DATA_DF)

# %%
def plot_GPS_G_Sum(
        df: pd.DataFrame,
        data_filepath: Optional[str] = None,
        save_plots: bool = True,
        show_plots: bool = False,
    ) -> None:
    save_or_show_plot(save_plots=save_plots, show_plots=show_plots)

    data_name = 'GPS G Sum'
    data_filepath = data_filepath if data_filepath is not None else RACE_DATA_FILEPATH

    plot_map_every_lap(
        df=df,
        data_to_plot=df[data_name],
        data_units=(u.m/(u.s**2)),
        colorbar_label='Acceleration (m/s^2)',
        tile_source=MapType.GOOGLE_SATELITE,
        data_filepath=data_filepath,
        save_plots=save_plots,
        show_plots=show_plots,
    )
    save_plot(data_filepath)

# plot_GPS_G_Sum(df=RACE_DATA_DF)

# %%
def plot_Acceleration(
        df: pd.DataFrame,
        data_filepath: Optional[str] = None,
        save_plots: bool = True,
        show_plots: bool = False,
    ) -> None:
    save_or_show_plot(save_plots=save_plots, show_plots=show_plots)

    data_name = 'Acceleration'
    colorbar_label = 'Acceleration [m/(s^2)]'
    data_filepath = data_filepath if data_filepath is not None else RACE_DATA_FILEPATH

    plot_map_every_lap(
        df=df,
        data_to_plot=df[data_name],
        data_units=(u.m/(u.s**2)),
        colorbar_label=colorbar_label,
        tile_source=MapType.GOOGLE_SATELITE,
        data_filepath=data_filepath,
        save_plots=save_plots,
        show_plots=show_plots,
    )

# plot_Acceleration(df=RACE_DATA_DF)

# %%
def plot_column_for_all_tracks(
        column_name: str,
        save_plots: bool = True,
        show_plots: bool = False,
    ) -> None:
    save_or_show_plot(save_plots=save_plots, show_plots=show_plots)

    data_files = get_data_files()

    for data_filepath in data_files:
        #### REMOVE LATER ####
        if data_filepath not in RACE_DATA_FILES_TO_USE:
            continue
        ######################
        UNITS: dict[str, str] = {}
        race_data_df = load_race(race_data_filepath=data_filepath, units=UNITS)
        plot_map_every_lap(
            df=race_data_df,
            data_to_plot=race_data_df[column_name],
            colorbar_label=f'{race_data_df[column_name].pint.units}',
            tile_source=MapType.GOOGLE_SATELITE,
            data_filepath=data_filepath,
            save_plots=save_plots,
            show_plots=show_plots,
        )

# plot_column_for_all_tracks(df=RACE_DATA_DF, column_name='GPS Speed')

# %%
def plot_all_columns(
        df: pd.DataFrame,
        data_filepath: Optional[str] = None,
        save_plots: bool = True,
        show_plots: bool = False,
    ) -> None:
    save_or_show_plot(save_plots=save_plots, show_plots=show_plots)

    data_filepath = data_filepath if data_filepath is not None else RACE_DATA_FILEPATH

    for data_column in df.columns:
        try:
            print(f'\tPLOTTING COLUMN:      \t{data_column}')
            data_units = df[data_column].pint.units
            plot_map_every_lap(
                df=df,
                data_to_plot=df[data_column],
                data_units=data_units,
                colorbar_label=f'{str(df[data_column].pint.dimensionality).capitalize()} ({data_units})',
                tile_source=MapType.GOOGLE_SATELITE,
                data_filepath=data_filepath,
                save_plots=save_plots,
                show_plots=show_plots,
            )
        except Exception as error:
            print(f'\tFAILED TO PLOT COLUMN:\t{data_column}')
            print(f'\t{error}')

# plot_all_columns(df=RACE_DATA_DF)

# %%
def plot_all_columns_for_all_tracks(
        save_plots: bool = True,
        show_plots: bool = False,
    ) -> None:
    save_or_show_plot(save_plots=save_plots, show_plots=show_plots)

    data_files = get_data_files()

    for data_filepath in data_files:
        #### REMOVE LATER ####
        if data_filepath not in RACE_DATA_FILES_TO_USE:
            continue
        ######################
        print(f'PLOTTING\t{get_filename(data_filepath)}')
        UNITS = {}
        race_data_df = load_race(race_data_filepath=data_filepath, units=UNITS)
        plot_all_columns(
            df=race_data_df,
            data_filepath=data_filepath,
            save_plots=save_plots,
            show_plots=show_plots,
        )

plot_all_columns_for_all_tracks()
